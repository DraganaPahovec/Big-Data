# %% [markdown]
# # Spark RDD (Workshop 2)
# ---

# %% [markdown]
# # Spark Context

# %%
! ls datasets
# Out:
# dataset.csv

# %%
from pyspark import SparkContext

sc = SparkContext()

# %% [markdown]
# # Read dataset to RDD

# %%
raw_data = sc.textFile("datasets/dataset.csv")

# %%
raw_data.take(10)
# Out:
# ['username,purchase',
#  '50888,473',
#  '9041985,738',
#  'rhbcnbyrf,444',
#  '29121986,690',
#  '301095,383',
#  '14021969,942',
#  '2071964,71',
#  '21071967,857',
#  '120976,488']

# %%
#take out the header
header = raw_data.first()
header_rdd = sc.parallelize([header])
input_data = raw_data.subtract(header_rdd)
input_data.take(10)
# Out:
# ['2access,54',
#  '3266,949',
#  'bonkers1,370',
#  'jamesj,250',
#  '22011997,867',
#  '260190,902',
#  '5325,247',
#  'hendri,482',
#  'impress,904',
#  '12081977,914']

# %% [markdown]
# # Process dataset

# %%
from collections import namedtuple

Record = namedtuple("Record", ["user", "purchase"])

def print_records(input_rdd):
    for record in input_rdd.take(10):
        print(record)

def to_number(x):
    return int(x)

def parse_record(x):
    elements = x.split(",")
    user, purchase = elements
    purchase = to_number(purchase)
    
    return Record(user, purchase)

parsed_data = input_data.map(parse_record)

print_records(parsed_data)
# Out:
# Record(user='2access', purchase=54)
# Record(user='3266', purchase=949)
# Record(user='bonkers1', purchase=370)
# Record(user='jamesj', purchase=250)
# Record(user='22011997', purchase=867)
# Record(user='260190', purchase=902)
# Record(user='5325', purchase=247)
# Record(user='hendri', purchase=482)
# Record(user='impress', purchase=904)
# Record(user='12081977', purchase=914)

# %%
volume = parsed_data.map(lambda x: x.purchase)
print_records(volume)
# Out:
# 54
# 949
# 370
# 250
# 867
# 902
# 247
# 482
# 904
# 914

# %% [markdown]
# ## 1. Find the average purchase of each user.

# %%
purchase_data = parsed_data.map(lambda x: (x.user, (x.purchase, 1)))
print_records(purchase_data)
# Out:
# ('2access', (54, 1))
# ('3266', (949, 1))
# ('bonkers1', (370, 1))
# ('jamesj', (250, 1))
# ('22011997', (867, 1))
# ('260190', (902, 1))
# ('5325', (247, 1))
# ('hendri', (482, 1))
# ('impress', (904, 1))
# ('12081977', (914, 1))

# %%
def f_count(x, y):
    x_purchase, x_count = x
    y_purchase, y_count = y
    return x_purchase + y_purchase, x_count + y_count

# %%
mean_data = purchase_data.reduceByKey(lambda x, y: f_count(x, y))
print_records(mean_data)
# Out:
# ('monitor3', (4308, 9))
# ('nikki123', (7545, 12))
# ('22111959', (2291, 7))
# ('mole', (9297, 20))
# ('james01', (4842, 9))
# ('25091983', (5573, 12))
# ('27-Aug', (2623, 7))
# ('meiner', (5065, 10))
# ('Porsche9', (4784, 12))
# ('BABYLON', (6448, 12))

# %%
def f_mean(x):
    x_purchase_sum, x_purchase_count = x
    return x_purchase_sum/x_purchase_count

# %%
final_mean_data = mean_data.map(lambda x: (x[0], f_mean(x[1])))

# %%
final_mean_data
# Out:
# PythonRDD[141] at RDD at PythonRDD.scala:53

# %% [markdown]
# ### 1.1. Sort result by average purchase amount in decreasing order.

# %%
sorted_data_desc = final_mean_data.sortBy(lambda x: x[1], ascending=False)

# %%
sorted_data_desc.take(20)
# Out:
# [('accessno', 958.0),
#  ('FORD', 956.25),
#  ('gigi', 946.5),
#  ('9071976', 935.5),
#  ('Blue1', 931.5),
#  ('18101961', 929.5),
#  ('6021969', 916.0),
#  ('madzia1', 915.75),
#  ('qqq123', 915.0),
#  ('peterj', 911.0),
#  ('antigone', 906.5),
#  ('4133', 900.25),
#  ('15121960', 900.0),
#  ('10691', 898.8),
#  ('darthvader', 898.5),
#  ('remembe', 898.0),
#  ('13011963', 897.25),
#  ('9394', 894.5),
#  ('kranta1', 892.0),
#  ('9021966', 889.0)]

# %% [markdown]
# ### 1.2. Store the sorted results in local disc.

# %%
sorted_data_desc.saveAsTextFile('output/sorted_data_desc/txt')

# %%
! ls output/sorted_data_desc/txt
# Out:
# part-00000  part-00003	part-00006  part-00009	part-00012
# part-00001  part-00004	part-00007  part-00010	part-00013
# part-00002  part-00005	part-00008  part-00011	_SUCCESS

# %%
! cat output/sorted_data_desc/txt/part-00000 | head
# Out:
# ('accessno', 958.0)
# ('FORD', 956.25)
# ('gigi', 946.5)
# ('9071976', 935.5)
# ('Blue1', 931.5)
# ('18101961', 929.5)
# ('6021969', 916.0)
# ('madzia1', 915.75)
# ('qqq123', 915.0)
# ('peterj', 911.0)
# cat: write error: Broken pipe

# %%
! cat output/sorted_data_desc/txt/part-00003 | head
# Out:
# ('qader', 561.1875)
# ('54132442', 561.1818181818181)
# ('magpies', 561.1818181818181)
# ('17111962', 561.1818181818181)
# ('300184', 561.1818181818181)
# ('goomba', 561.1666666666666)
# ('24041975', 561.1666666666666)
# ('boosted', 561.1666666666666)
# ('krypton', 561.1666666666666)
# ('1Samanth', 561.1666666666666)
# cat: write error: Broken pipe

# %% [markdown]
# ### 1.3. Print the first 20 rows of the sorted dataset.

# %%
sorted_data_desc.take(20)
# Out:
# [('accessno', 958.0),
#  ('FORD', 956.25),
#  ('gigi', 946.5),
#  ('9071976', 935.5),
#  ('Blue1', 931.5),
#  ('18101961', 929.5),
#  ('6021969', 916.0),
#  ('madzia1', 915.75),
#  ('qqq123', 915.0),
#  ('peterj', 911.0),
#  ('antigone', 906.5),
#  ('4133', 900.25),
#  ('15121960', 900.0),
#  ('10691', 898.8),
#  ('darthvader', 898.5),
#  ('remembe', 898.0),
#  ('13011963', 897.25),
#  ('9394', 894.5),
#  ('kranta1', 892.0),
#  ('9021966', 889.0)]

# %%
type(sorted_data_desc)
# Out:
# pyspark.rdd.PipelinedRDD

# %% [markdown]
# ## 2. Filter the average purchase of each user dataset (the dataset formed during Task 1), and keep all data rows where purchase >100 and purchase < 900.

# %%
avg_btw_100_900 = sorted_data_desc.filter(lambda x: x[1] > 100 and x[1] < 900).collect()

# %%
avg_btw_100_900
# Out:
# [('10691', 898.8),
#  ('darthvader', 898.5),
#  ('remembe', 898.0),
#  ('13011963', 897.25),
#  ('9394', 894.5),
#  ('kranta1', 892.0),
#  ('9021966', 889.0),
#  ('31101965', 889.0),
#  ('bykemo', 886.3333333333334),
#  ('nivek1', 885.5714285714286),
#  ('18111983', 885.4),
#  ('260980', 882.5),
#  ('981', 882.5),
#  ('25051970', 881.6),
#  ('openopen', 879.0),
#  ('70861', 878.4),
#  ('4268', 877.0),
#  ('cloud', 875.6666666666666),
#  ('151065', 874.0),
#  ('galatasara', 874.0),
#  ('Zealots', 871.75),
#  ('lyndon', 869.5),
#  ('muffin12', 868.5),
#  ('stunner1', 867.5),
#  ('Hd764nW5d7E1vb1', 865.3333333333334),
#  ('nyranger', 860.6666666666666),
#  ('21081', 860.3333333333334),
#  ('150495', 858.2),
#  ('larsen', 855.6666666666666),
#  ('squids', 855.5),
#  ('john1968', 855.3333333333334),
#  ('beachs', 854.4285714285714),
#  ('gandalf0', 853.5),
#  ('gritty', 853.0),
#  ('motorhead', 851.0),
#  ('just1n', 850.8571428571429),
#  ('reaper1', 850.6666666666666),
#  ('mcgraw', 848.0),
#  ('thelast1', 847.8),
#  ('11081987', 847.75),
#  ('20051992', 847.3333333333334),
#  ('pluck', 846.3333333333334),
#  ('parazit', 846.25),
#  ('necronomicon', 844.0),
#  ('180558', 843.5),
#  ('yong', 841.6666666666666),
#  ('lillian', 841.0),
#  ('fktif6115', 841.0),
#  ('fathead1', 840.0),
#  ('161072', 838.75),
#  ('plug', 838.75),
#  ('caocao', 838.625),
#  ('17031990', 838.4444444444445),
#  ('18021966', 838.2),
#  ('rosco', 837.1666666666666),
#  ('kath', 834.8333333333334),
#  ('jansson', 833.5),
#  ('tos8217', 833.4),
#  ('2870', 833.0),
#  ('jet123', 833.0),
#  ('389', 833.0),
#  ('rebeka', 832.6666666666666),
#  ('nigger1', 831.5),
#  ('hairyass', 831.3333333333334),
#  ('18040', 830.25),
#  ('power1', 830.0),
#  ('cyclope', 828.0),
#  ('goatman', 827.0),
#  ('gsxr600', 826.0),
#  ('pounding', 825.75),
#  ('GOLDEN', 825.6666666666666),
#  ('171198', 825.375),
#  ('vinegar', 825.0),
#  ('Cool1', 824.75),
#  ('alemania', 824.6666666666666),
#  ('291277', 823.75),
#  ('90778', 823.6666666666666),
#  ('poiulkjh', 823.2),
#  ('manifold', 823.0),
#  ('kati', 822.0),
#  ('trench', 821.6),
#  ('lavern', 821.5),
#  ('7081980', 821.2),
#  ('gabrielle', 820.75),
#  ('241062', 820.0),
#  ('pantheon', 820.0),
#  ('120893', 819.6),
#  ('290862', 819.375),
#  ('25091975', 819.2857142857143),
#  ('220698', 819.25),
#  ('150972', 819.0),
#  ('1478523', 818.8),
#  ('15021994', 818.2),
#  ('gulmira', 817.8333333333334),
#  ('18051995', 816.8888888888889),
#  ('admirer', 816.375),
#  ('1021977', 815.75),
#  ('alpha3', 815.4285714285714),
#  ('pauli', 815.2),
#  ('huey', 815.1666666666666),
#  ('kopet', 814.6),
#  ('sabbat', 814.0),
#  ('simba01', 813.6666666666666),
#  ('fabius', 813.25),
#  ('scramble', 812.6666666666666),
#  ('flower12', 812.5),
#  ('seaquest', 812.5),
#  ('man1', 812.3333333333334),
#  ('11117', 812.3076923076923),
#  ('orlando1', 812.2),
#  ('ballsack', 812.0),
#  ('1234567u', 811.8),
#  ('MORGAN', 811.75),
#  ('18051964', 811.2857142857143),
#  ('bionic', 810.875),
#  ('faisal', 810.8),
#  ('130983', 810.5714285714286),
#  ('2531', 810.5714285714286),
#  ('fiction', 810.0),
#  ('2112000', 810.0),
#  ('19071989', 810.0),
#  ('modular', 809.8333333333334),
#  ('bald', 809.8),
#  ('barnett', 809.4),
#  ('5t4r3e2w1q', 809.0),
#  ('gashish', 809.0),
#  ('40381', 808.6363636363636),
#  ('1Jennife', 808.0),
#  ('271273', 808.0),
#  ('70880', 807.6666666666666),
#  ('deflep', 807.5),
#  ('pinkpink', 807.3),
#  ('carioca', 807.2),
#  ('19031979', 807.0),
#  ('1a2a3a', 807.0),
#  ('funnies', 806.8571428571429),
#  ('beto', 806.75),
#  ('mmmmmmmmm', 806.3333333333334),
#  ('bruno12', 806.1666666666666),
#  ('26091962', 806.1428571428571),
#  ('210182', 805.6666666666666),
#  ('rasputin', 805.5555555555555),
#  ('romulan', 805.3333333333334),
#  ('1.23457E+16', 805.0),
#  ('30963', 804.375),
#  ('5031995', 804.1666666666666),
#  ('jktujktu', 803.8571428571429),
#  ('19011968', 803.6),
#  ('27081984', 803.6),
#  ('drew', 803.5),
#  ('18031954', 802.5714285714286),
#  ('30041990', 802.5),
#  ('18021994', 802.4),
#  ('failed', 802.375),
#  ('overcome', 801.5),
#  ('minnesot', 800.6666666666666),
#  ('esmith', 800.375),
#  ('lunatik', 800.25),
#  ('lanka', 800.2),
#  ('6091959', 800.1666666666666),
#  ('bakayaro', 799.5),
#  ('dima1234', 799.5),
#  ('rapeme', 799.4444444444445),
#  ('spamspam', 799.3333333333334),
#  ('2829', 798.6),
#  ('bellagio', 798.5),
#  ('18112005', 798.3333333333334),
#  ('21081961', 798.25),
#  ('nfgbpltwq', 798.2222222222222),
#  ('DOLPHINS', 798.0),
#  ('19071995', 798.0),
#  ('121092', 798.0),
#  ('sondra', 798.0),
#  ('1Gateway', 796.625),
#  ('9051996', 796.5),
#  ('1215', 796.2857142857143),
#  ('10088', 796.25),
#  ('19051978', 796.25),
#  ('pepper11', 796.1666666666666),
#  ('1574', 796.0),
#  ('170787', 796.0),
#  ('lirika', 795.8),
#  ('strip4me', 795.6666666666666),
#  ('kegger', 795.5),
#  ('meoff', 795.5),
#  ('300391', 795.25),
#  ('ernst', 795.0),
#  ('purple22', 794.8571428571429),
#  ('webguy', 794.6666666666666),
#  ('26071970', 794.6666666666666),
#  ('leftie', 794.3333333333334),
#  ('6233', 794.2857142857143),
#  ('origin', 794.0),
#  ('13101960', 793.6666666666666),
#  ('jardin', 793.625),
#  ('stealth2', 793.5),
#  ('4332', 793.5),
#  ('lannie', 793.0),
#  ('manning1', 792.5),
#  ('junk', 792.4285714285714),
#  ('2173', 792.3333333333334),
#  ('199111', 792.2857142857143),
#  ('fantasy7', 792.2857142857143),
#  ('180484', 792.2),
#  ('300671', 792.1666666666666),
#  ('roadking', 792.0),
#  ('gnosis', 792.0),
#  ('peacenow', 791.6),
#  ('17061979', 791.5),
#  ('Gotcha', 791.0),
#  ('c1234567', 790.8333333333334),
#  ('thrash', 790.8),
#  ('A1234567', 790.5555555555555),
#  ('thorthor', 790.5),
#  ('chatting', 790.2),
#  ('1111961', 790.2),
#  ('1091973', 790.0),
#  ('freddi', 789.8),
#  ('futile', 789.5),
#  ('36985214', 789.4285714285714),
#  ('Cookie', 789.3333333333334),
#  ('morgan23', 789.25),
#  ('asshead', 789.1428571428571),
#  ('topless', 788.8888888888889),
#  ('2011999', 788.75),
#  ('130180', 788.5714285714286),
#  ('castell', 788.5),
#  ('jo9k2jw2', 788.5),
#  ('100975', 788.5),
#  ('hardaway', 788.3333333333334),
#  ('9041967', 788.2),
#  ('40987', 788.0),
#  ('25091998', 787.7777777777778),
#  ('gameover', 787.5),
#  ('1qwerty', 787.3),
#  ('autism', 787.0),
#  ('21021958', 787.0),
#  ('gumper', 786.7142857142857),
#  ('ilovelucy', 786.6666666666666),
#  ('romaska', 786.5714285714286),
#  ('20041981', 786.1666666666666),
#  ('spanky11', 786.0),
#  ('steelers', 786.0),
#  ('30374', 786.0),
#  ('51270', 785.8333333333334),
#  ('18021965', 785.8333333333334),
#  ('hollaback', 785.8),
#  ('maribel', 785.6153846153846),
#  ('ladiesman', 785.4285714285714),
#  ('rs2000', 785.4),
#  ('ciccone', 785.375),
#  ('adelaide', 785.3333333333334),
#  ('rags', 785.0),
#  ('horde', 785.0),
#  ('91279', 784.6666666666666),
#  ('fy.nrf', 784.5),
#  ('meeker', 784.5),
#  ('6081976', 784.3333333333334),
#  ('29051963', 784.1666666666666),
#  ('260481', 784.1428571428571),
#  ('Jimmy', 784.0),
#  ('zipp', 784.0),
#  ('Lzhan16889', 783.5),
#  ('241971', 783.4),
#  ('29071998', 783.3333333333334),
#  ('neutrino', 783.2),
#  ('220578', 783.1666666666666),
#  ('24011998', 783.1111111111111),
#  ('11121976', 783.0),
#  ('bigfoo', 783.0),
#  ('hoosier1', 783.0),
#  ('141183', 782.6666666666666),
#  ('protocol', 782.5),
#  ('bootboy', 782.4285714285714),
#  ('pictuers', 782.0),
#  ('17081973', 781.8),
#  ('bondages', 781.6666666666666),
#  ('1101987', 781.6666666666666),
#  ('4959', 781.6666666666666),
#  ('110976', 781.6),
#  ('281079', 781.4444444444445),
#  ('beagles', 781.2727272727273),
#  ('all4love', 781.25),
#  ('milan1899', 780.5714285714286),
#  ('cosita', 780.3333333333334),
#  ('300692', 779.8333333333334),
#  ('20011958', 779.75),
#  ('Mercedes', 779.5714285714286),
#  ('140140', 779.5),
#  ('damore', 779.5),
#  ('joWgNx', 778.75),
#  ('4782', 778.75),
#  ('130668', 778.7142857142857),
#  ('souvenir', 778.7),
#  ('kobe66661', 778.5),
#  ('jaysoncj', 778.375),
#  ('14021975', 778.3333333333334),
#  ('2662', 778.1428571428571),
#  ('16051975', 778.0),
#  ('40668', 777.8),
#  ('blockbus', 777.75),
#  ('70192', 777.6666666666666),
#  ('Kondom25', 777.5714285714286),
#  ('regit', 777.5714285714286),
#  ('110977', 777.4444444444445),
#  ('Bigdick1', 777.4),
#  ('12091969', 777.25),
#  ('21101986', 777.0),
#  ('infantry', 776.8571428571429),
#  ('timberwolf', 776.5384615384615),
#  ('dfkthbz', 776.3333333333334),
#  ('flicker', 776.0),
#  ('enormous', 776.0),
#  ('sammy69', 776.0),
#  ('brett', 775.8571428571429),
#  ('paiste', 775.8333333333334),
#  ('8523', 775.5),
#  ('travel', 775.5),
#  ('258036', 775.5),
#  ('fyutkbyf', 775.25),
#  ('24121976', 775.1111111111111),
#  ('windows7', 774.8),
#  ('3112000', 774.5555555555555),
#  ('280577', 774.5),
#  ('raster', 774.5),
#  ('28062000', 774.2),
#  ('11081980', 774.0),
#  ('18041986', 773.75),
#  ('audra', 773.4),
#  ('2549', 773.3333333333334),
#  ('croco', 773.3333333333334),
#  ('322322', 772.875),
#  ('keywest', 772.7142857142857),
#  ('160579', 772.2142857142857),
#  ('280686', 772.1428571428571),
#  ('CidKid86', 772.0),
#  ('lhbjkjubz2957704', 772.0),
#  ('dawn', 772.0),
#  ('icon', 771.8571428571429),
#  ('grinding', 771.8333333333334),
#  ('spells', 771.6666666666666),
#  ('270185', 771.5),
#  ('thehip', 771.4444444444445),
#  ('15101996', 771.4),
#  ('15151515', 771.4),
#  ('201067', 771.3333333333334),
#  ('urinal', 771.3333333333334),
#  ('2071989', 771.3),
#  ('style', 771.25),
#  ('187211', 771.2),
#  ('hackedit', 770.8),
#  ('28021975', 770.8),
#  ('102769', 770.6666666666666),
#  ('charts', 770.6666666666666),
#  ('454987', 770.4),
#  ('entre', 770.2222222222222),
#  ('hella', 769.875),
#  ('28071983', 769.8),
#  ('jetsfan', 769.75),
#  ('gabit', 769.6),
#  ('nitty', 769.5555555555555),
#  ('23031967', 769.5454545454545),
#  ('zip100', 769.5),
#  ('Install', 769.5),
#  ('pennies', 769.2),
#  ('litvin', 769.0),
#  ('lkjasd', 769.0),
#  ('1401', 769.0),
#  ('cheri', 769.0),
#  ('31082', 768.875),
#  ('kerry', 768.8333333333334),
#  ('deja', 768.8),
#  ('13-Jun', 768.8),
#  ('problem', 768.625),
#  ('watchers', 768.5),
#  ('kailee', 768.4),
#  ('Natasha1', 768.2857142857143),
#  ('pashka', 768.1428571428571),
#  ('7011992', 768.0),
#  ('13081976', 768.0),
#  ('261072', 768.0),
#  ('bhfbhf', 768.0),
#  ('2091969', 767.8333333333334),
#  ('flatron1', 767.8),
#  ('betina', 767.6666666666666),
#  ('mooch', 767.5714285714286),
#  ('290876', 767.5),
#  ('RAINBOW', 767.5),
#  ('13021988', 767.375),
#  ('onions', 767.2857142857143),
#  ('220993', 767.25),
#  ('27011954', 767.25),
#  ('qwerty3', 767.1818181818181),
#  ('11263', 767.1666666666666),
#  ('fluffy', 767.0),
#  ('281168', 767.0),
#  ('pass1', 766.8333333333334),
#  ('Jenny1', 766.8181818181819),
#  ('211072', 766.7),
#  ('alpha06', 766.6666666666666),
#  ('yCWVrxXH', 766.6666666666666),
#  ('greenday1', 766.5),
#  ('villain', 766.5),
#  ('dirtyone', 766.5),
#  ('applegat', 766.4),
#  ('241291', 766.3333333333334),
#  ('220869', 766.2857142857143),
#  ('290193', 766.0),
#  ('chippy', 765.8),
#  ('28041974', 765.6923076923077),
#  ('vfhujif', 765.6),
#  ('30091971', 765.4),
#  ('nokiax2', 765.2727272727273),
#  ('130790', 765.125),
#  ('240968', 765.0),
#  ('loud', 764.7142857142857),
#  ('27011960', 764.4285714285714),
#  ('31299', 764.2),
#  ('leto', 764.0),
#  ('ferrari360', 764.0),
#  ('221086', 763.9090909090909),
#  ('29111997', 763.8),
#  ('777777777', 763.7142857142857),
#  ('pass111', 763.6666666666666),
#  ('stomatolog', 763.6666666666666),
#  ('smokeweed', 763.4285714285714),
#  ('51291', 763.4285714285714),
#  ('416', 763.25),
#  ('880888', 763.1111111111111),
#  ('warlords', 763.0833333333334),
#  ('27081982', 763.0),
#  ('6181', 762.75),
#  ('Ranger1', 762.7142857142857),
#  ('fate', 762.6),
#  ('griffin1', 762.5714285714286),
#  ('batistut', 762.5),
#  ('dropzone', 762.5),
#  ('apple5', 762.4),
#  ('braveheart', 762.2857142857143),
#  ('fiorentina', 762.25),
#  ('cingular', 762.2),
#  ('pitstop', 762.1428571428571),
#  ('downset', 762.125),
#  ('sheetz', 762.0833333333334),
#  ('inuyasha', 762.0),
#  ('27031973', 762.0),
#  ('280778', 762.0),
#  ('islands', 762.0),
#  ('esteba', 762.0),
#  ('suckass', 761.9),
#  ('daxada', 761.8),
#  ('12121995', 761.75),
#  ('81171', 761.75),
#  ('18031985', 761.6666666666666),
#  ('197706', 761.625),
#  ('31071985', 761.5555555555555),
#  ('drayton', 761.5),
#  ('100200300', 761.3333333333334),
#  ('1Marine', 761.1428571428571),
#  ('nhjkkm', 761.0),
#  ('micheal', 761.0),
#  ('1Mine', 760.8),
#  ('hpotter', 760.7777777777778),
#  ('170176', 760.5),
#  ('2091966', 760.5),
#  ('19951996', 760.4285714285714),
#  ('eddings', 760.25),
#  ('140675', 760.2),
#  ('buyer', 760.1666666666666),
#  ('1062', 760.0),
#  ('devilman', 759.875),
#  ('kalinina', 759.5),
#  ('27041985', 759.5),
#  ('iggy', 759.25),
#  ('22132213', 759.2),
#  ('zander', 759.0),
#  ('3524', 758.875),
#  ('export', 758.8),
#  ('watts', 758.6666666666666),
#  ('bourque', 758.5),
#  ('110679', 758.4285714285714),
#  ('redneck', 758.3333333333334),
#  ('rinker', 758.1818181818181),
#  ('weed', 758.1666666666666),
#  ('cdcdcd', 758.1111111111111),
#  ('utica', 758.0),
#  ('doublet', 758.0),
#  ('arrow', 758.0),
#  ('221982', 757.9230769230769),
#  ('bigass', 757.75),
#  ('1Love', 757.4),
#  ('cryptic', 757.25),
#  ('81089', 757.25),
#  ('8252', 757.125),
#  ('1Jasper', 757.1),
#  ('marriage', 757.0),
#  ('daruma', 757.0),
#  ('emerso', 756.6666666666666),
#  ('iamtheone', 756.5714285714286),
#  ('6912', 756.5),
#  ('241269', 756.4),
#  ('shortman', 756.3),
#  ('logon1', 756.0),
#  ('258', 756.0),
#  ('embers', 756.0),
#  ('dragon2', 756.0),
#  ('wisconsi', 755.9090909090909),
#  ('braves10', 755.8333333333334),
#  ('200684', 755.8),
#  ('270277', 755.3333333333334),
#  ('formic', 755.2727272727273),
#  ('3123', 755.1666666666666),
#  ('firedog', 755.0),
#  ('220473', 755.0),
#  ('7011990', 755.0),
#  ('laszlo', 755.0),
#  ('raul', 754.8333333333334),
#  ('good4u', 754.7777777777778),
#  ('31031987', 754.5),
#  ('4352', 754.5),
#  ('fender', 754.3333333333334),
#  ('111111d', 754.3333333333334),
#  ('1136', 754.3333333333334),
#  ('310872', 754.25),
#  ('6966', 754.125),
#  ('vikings1', 754.1111111111111),
#  ('30101989', 754.0),
#  ('mad123', 754.0),
#  ('1111979', 753.875),
#  ('210878', 753.875),
#  ('freezer', 753.8571428571429),
#  ('eliz', 753.8333333333334),
#  ('27051998', 753.8),
#  ('vytautas', 753.7777777777778),
#  ('27091980', 753.75),
#  ('hootch', 753.6666666666666),
#  ('70378', 753.6666666666666),
#  ('rhfvfnjhcr', 753.6666666666666),
#  ('derf', 753.625),
#  ('cork', 753.5555555555555),
#  ('15121999', 753.5),
#  ('171270', 753.4166666666666),
#  ('freepussy', 753.4),
#  ('womens', 753.375),
#  ('30396', 753.0),
#  ('escorpi', 753.0),
#  ('melly', 753.0),
#  ('couples', 752.8888888888889),
#  ('strudel', 752.8571428571429),
#  ('elliot1', 752.7142857142857),
#  ('31011988', 752.6),
#  ('houser', 752.5555555555555),
#  ('schnecke', 752.5),
#  ('bananas', 752.5),
#  ('ashutosh', 752.3333333333334),
#  ('5041993', 752.3333333333334),
#  ('PtBDHW', 752.2),
#  ('112371', 752.0),
#  ('caballer', 752.0),
#  ('cheating', 752.0),
#  ('20081973', 752.0),
#  ('27011959', 752.0),
#  ('9200', 751.875),
#  ('rush11', 751.875),
#  ('awesome', 751.8),
#  ('201020', 751.7777777777778),
#  ('150776', 751.75),
#  ('loki99', 751.75),
#  ('vinter', 751.6),
#  ('12051987', 751.5714285714286),
#  ('310577', 751.5),
#  ('17051970', 751.5),
#  ('polin', 751.4),
#  ('sexkitte', 751.1428571428571),
#  ('240574', 751.125),
#  ('tiger6', 751.0),
#  ('101011', 750.8333333333334),
#  ('230271', 750.8),
#  ('20776', 750.625),
#  ('20031960', 750.5714285714286),
#  ('killing', 750.5),
#  ('172839', 750.4166666666666),
#  ('eckerd', 750.4),
#  ('marios', 750.375),
#  ('flashbac', 750.2857142857143),
#  ('carlisle', 750.2727272727273),
#  ('riggins', 750.1666666666666),
#  ('4082000', 750.1428571428571),
#  ('stussy', 750.0),
#  ('acuransx', 749.75),
#  ('slyder', 749.75),
#  ('987410', 749.6923076923077),
#  ('kinkos', 749.5714285714286),
#  ('22091982', 749.5384615384615),
#  ('venkata', 749.5),
#  ('othello', 749.4285714285714),
#  ('troop', 749.3333333333334),
#  ('20091989', 749.2857142857143),
#  ('hyundai', 749.2222222222222),
#  ('monitor4', 749.125),
#  ('120961', 749.0),
#  ('samcat', 748.8571428571429),
#  ('soller', 748.8181818181819),
#  ('roll', 748.8),
#  ('criket', 748.75),
#  ('180675', 748.7),
#  ('redrange', 748.6666666666666),
#  ('guards', 748.5833333333334),
#  ('261187', 748.5714285714286),
#  ('chance', 748.5),
#  ('super21', 748.5),
#  ('113411', 748.4),
#  ('popcorn1', 748.3333333333334),
#  ('igromania', 748.3333333333334),
#  ('joesmith', 748.3333333333334),
#  ('Pumpkin1', 748.25),
#  ('bullshi', 748.2),
#  ('cash', 748.125),
#  ('malaki', 748.0909090909091),
#  ('sweet12', 748.0),
#  ('andyod22', 747.6666666666666),
#  ('nascar24', 747.6153846153846),
#  ('ToNNa', 747.6),
#  ('31081986', 747.4444444444445),
#  ('250883', 747.4),
#  ('29082000', 747.4),
#  ('201191', 747.25),
#  ('lplplp', 747.25),
#  ('29071965', 747.2),
#  ('redtruck', 747.1666666666666),
#  ('marine1', 747.1111111111111),
#  ('198206', 747.0),
#  ('8121983', 747.0),
#  ('housewifes', 747.0),
#  ('aprile', 747.0),
#  ('porsche', 747.0),
#  ('11101972', 747.0),
#  ('speedy12', 746.8571428571429),
#  ('titties', 746.8333333333334),
#  ('samuel01', 746.75),
#  ('thump', 746.5),
#  ('flynavy', 746.4615384615385),
#  ('powpow', 746.4285714285714),
#  ('sexym', 746.4),
#  ('navyseal', 746.4),
#  ('test12', 746.375),
#  ('koufax', 746.3333333333334),
#  ('413413', 746.3),
#  ('zonker', 746.2),
#  ('mybutt', 746.1666666666666),
#  ('1140', 746.0),
#  ('breath', 746.0),
#  ('freesurf', 746.0),
#  ('sluts', 745.6363636363636),
#  ('270570', 745.5714285714286),
#  ('dt426a37', 745.5),
#  ('passover', 745.5),
#  ('thumb', 745.5),
#  ('katt', 745.5),
#  ('Fishing', 745.5),
#  ('Nnnnnn1', 745.4),
#  ('260796', 745.4),
#  ('dell1234', 745.25),
#  ('112270', 745.2),
#  ('sarita2', 745.2),
#  ('301169', 745.1111111111111),
#  ('magal', 745.1),
#  ('yoghurt', 745.0714285714286),
#  ('raiser', 745.0),
#  ('vaz2109', 745.0),
#  ('darock', 745.0),
#  ('241263', 744.8666666666667),
#  ('10021963', 744.6153846153846),
#  ('aspirine', 744.6),
#  ('dave2', 744.5555555555555),
#  ('fatbob', 744.5),
#  ('ch3ch2oh', 744.4444444444445),
#  ('aksana', 744.4),
#  ('viper666', 744.3333333333334),
#  ('brainiac', 744.0),
#  ('100692', 744.0),
#  ('gtnheirf', 744.0),
#  ('7576', 744.0),
#  ('menow', 743.9166666666666),
#  ('87654321', 743.8571428571429),
#  ('reborn', 743.6923076923077),
#  ('snook1', 743.6666666666666),
#  ('crazydude', 743.6),
#  ('sergey12', 743.6),
#  ('29071979', 743.4285714285714),
#  ('plaster', 743.2),
#  ('24242', 743.1428571428571),
#  ('masahiro', 743.1428571428571),
#  ('18091967', 743.1),
#  ('jerico', 743.0),
#  ('owen', 743.0),
#  ('3422', 743.0),
#  ('moocow', 743.0),
#  ('110884', 743.0),
#  ('earlgrey', 742.8181818181819),
#  ('damdam', 742.75),
#  ('10873', 742.6),
#  ('azxs', 742.5),
#  ('240972', 742.4444444444445),
#  ('12201220', 742.4),
#  ('imfree', 742.4),
#  ('kayley', 742.3846153846154),
#  ('5101983', 742.375),
#  ('Beethove', 742.3333333333334),
#  ('filip', 742.3333333333334),
#  ('100578', 742.25),
#  ('5870587', 742.1666666666666),
#  ('gatorfan', 742.1666666666666),
#  ('strawberry', 742.1428571428571),
#  ('7021978', 742.0),
#  ('111870', 742.0),
#  ('baldman', 741.8888888888889),
#  ('welcome4', 741.8888888888889),
#  ('27061971', 741.8),
#  ('swimmin', 741.75),
#  ('5437', 741.7272727272727),
#  ('searcher', 741.6666666666666),
#  ('2155', 741.625),
#  ('surgeon', 741.4166666666666),
#  ('mikel', 741.4),
#  ('Junior1', 741.4),
#  ('120600', 741.3333333333334),
#  ('nailer', 741.2),
#  ('5011994', 741.2),
#  ('Packers', 741.1666666666666),
#  ('2152', 741.1428571428571),
#  ('babe69', 741.0),
#  ('16111967', 740.7777777777778),
#  ('21031976', 740.75),
#  ('14071956', 740.75),
#  ('27101989', 740.7142857142857),
#  ('4634', 740.6923076923077),
#  ('698', 740.5833333333334),
#  ('fuckings', 740.5714285714286),
#  ('16121978', 740.5714285714286),
#  ('playas', 740.5),
#  ('13117', 740.4285714285714),
#  ('radost', 740.375),
#  ('sofie', 740.3636363636364),
#  ('mason', 740.25),
#  ('370370', 740.2307692307693),
#  ('feature', 740.2),
#  ('topaz1', 740.1538461538462),
#  ('10041965', 740.125),
#  ('14021998', 740.125),
#  ('Alice', 740.0),
#  ('cuzz', 740.0),
#  ('golde', 740.0),
#  ('20566', 740.0),
#  ('isabel', 739.8571428571429),
#  ('virtual', 739.8571428571429),
#  ('11061984', 739.8333333333334),
#  ('owned', 739.8),
#  ('111294', 739.75),
#  ('anatomy', 739.7142857142857),
#  ('280668', 739.6),
#  ('gjkbyjxrf', 739.4444444444445),
#  ('design1', 739.3333333333334),
#  ('supersex', 739.3333333333334),
#  ('12031957', 739.3333333333334),
#  ('asdzxc123', 739.2),
#  ('220790', 739.1428571428571),
#  ('81075', 739.0),
#  ('12051975', 739.0),
#  ('kbytqrfpkj', 739.0),
#  ('1379', 739.0),
#  ('jrock', 739.0),
#  ('kensingt', 739.0),
#  ('cubano', 739.0),
#  ('90670', 738.75),
#  ('1121989', 738.75),
#  ('4101996', 738.7272727272727),
#  ('jonathon', 738.7272727272727),
#  ('7091987', 738.6666666666666),
#  ('tom1', 738.5555555555555),
#  ('1Drummer', 738.5),
#  ('26051961', 738.5),
#  ('14031984', 738.5),
#  ('220474', 738.5),
#  ('mike33', 738.5),
#  ('roma1234', 738.5),
#  ('q1w2e3r4t', 738.5),
#  ('12345679', 738.5),
#  ('football1', 738.5),
#  ('zircon', 738.4545454545455),
#  ('FERRARI', 738.3333333333334),
#  ('mark11', 738.2857142857143),
#  ('220302', 738.2857142857143),
#  ('gfifgfif', 738.1111111111111),
#  ('gb2312', 738.1),
#  ('ghfdlf', 738.0),
#  ('shotgun', 738.0),
#  ('2403082', 738.0),
#  ('corliss', 737.875),
#  ('bubblegu', 737.875),
#  ('4081982', 737.875),
#  ('17031974', 737.8666666666667),
#  ('spitball', 737.8181818181819),
#  ('fuerte', 737.8125),
#  ('30121984', 737.6666666666666),
#  ('motorcycle', 737.4545454545455),
#  ('10081984', 737.4),
#  ('170460', 737.375),
#  ('230462', 737.3333333333334),
#  ('270184', 737.3333333333334),
#  ('frozenfish', 737.2857142857143),
#  ('26111977', 737.25),
#  ('6336', 737.25),
#  ('1051976', 737.25),
#  ('11071964', 737.25),
#  ('240887', 737.2),
#  ('111568', 737.0),
#  ('qwert1234', 737.0),
#  ('13erin3', 737.0),
#  ('26117', 737.0),
#  ('qwerfdsa', 737.0),
#  ('satellit', 736.9090909090909),
#  ('10385', 736.875),
#  ('25111997', 736.8333333333334),
#  ('siva', 736.7142857142857),
#  ('160984', 736.6666666666666),
#  ('charlied', 736.6363636363636),
#  ('mosher', 736.6),
#  ('sokol1', 736.5714285714286),
#  ('jone', 736.5),
#  ('3042003', 736.5),
#  ('16111972', 736.375),
#  ('130496', 736.375),
#  ('miro', 736.3636363636364),
#  ('santande', 736.3571428571429),
#  ('25051971', 736.3333333333334),
#  ('q12345q', 736.25),
#  ('pcgamer', 736.25),
#  ('bendix', 736.2222222222222),
#  ('king01', 736.2),
#  ('sapphira', 736.1111111111111),
#  ('9071967', 736.1111111111111),
#  ('tihonov', 736.0),
#  ('desktop1', 735.9090909090909),
#  ('3091985', 735.8571428571429),
#  ('anelka', 735.8571428571429),
#  ('cassiope', 735.8333333333334),
#  ('160880', 735.8333333333334),
#  ('barry', 735.8),
#  ('providian', 735.6666666666666),
#  ('christina', 735.6666666666666),
#  ('30101963', 735.5555555555555),
#  ('LOVER', 735.5),
#  ('6031965', 735.5),
#  ('rashmi', 735.5),
#  ('girlygirl', 735.5),
#  ('avante', 735.4444444444445),
#  ('bestfriend', 735.375),
#  ('sdh686drth', 735.375),
#  ('89128830153', 735.3333333333334),
#  ('jennyfer', 735.3333333333334),
#  ('woodgoat', 735.2),
#  ('crispin', 735.0),
#  ('chicca', 735.0),
#  ('2137', 735.0),
#  ('zlatan', 735.0),
#  ('230797', 735.0),
#  ('BOOBOO', 734.875),
#  ('stutter', 734.875),
#  ('babababa', 734.875),
#  ('608', 734.8571428571429),
#  ('bighead', 734.7777777777778),
#  ('bowers', 734.7142857142857),
#  ('christo', 734.6),
#  ('chasm', 734.5555555555555),
#  ('11051970', 734.5384615384615),
#  ('marceau', 734.5),
#  ('flamer', 734.5),
#  ('spite', 734.2),
#  ('171169', 734.2),
#  ('litebeer', 734.2),
#  ('akademia', 734.1666666666666),
#  ('558855', 734.1666666666666),
#  ('7061983', 734.125),
#  ('santan', 734.0769230769231),
#  ('1Billy', 734.0),
#  ('2101959', 734.0),
#  ('winnipeg', 734.0),
#  ('hotsauce', 733.8),
#  ('karizma', 733.8),
#  ('197219', 733.8),
#  ('hubbell', 733.75),
#  ('torsten', 733.75),
#  ('bushes', 733.6666666666666),
#  ('200794', 733.6666666666666),
#  ('itdoes', 733.6),
#  ('pastel', 733.6),
#  ('florian', 733.5833333333334),
#  ('mage', 733.5),
#  ('180369', 733.375),
#  ('990', 733.3333333333334),
#  ('mundaka', 733.25),
#  ('70173', 733.2222222222222),
#  ('4130', 733.2),
#  ('harley69', 733.1666666666666),
#  ('7091964', 733.1),
#  ('lovesyou', 733.0),
#  ('cfvfzkexifz', 733.0),
#  ('delta12', 733.0),
#  ('1575', 733.0),
#  ('oriental', 733.0),
#  ('270278', 732.8888888888889),
#  ('321677', 732.8571428571429),
#  ('psalm23', 732.8333333333334),
#  ('121473', 732.8),
#  ('270765', 732.8),
#  ('13091991', 732.8),
#  ('131092', 732.8),
#  ('10021996', 732.7142857142857),
#  ('19111984', 732.7142857142857),
#  ('sasha1985', 732.7),
#  ('olietjoc', 732.6666666666666),
#  ('10071956', 732.6666666666666),
#  ('eruption', 732.625),
#  ('12041993', 732.625),
#  ('26081974', 732.5714285714286),
#  ('55775577', 732.5714285714286),
#  ('24101996', 732.5),
#  ('benedikt', 732.4),
#  ('41093', 732.3333333333334),
#  ('rashid', 732.3333333333334),
#  ('12051979', 732.3333333333334),
#  ('29041988', 732.3333333333334),
#  ('filipina', 732.3333333333334),
#  ('333333q', 732.2857142857143),
#  ('logistics', 732.2727272727273),
#  ('karasik', 732.1111111111111),
#  ('tessadog', 732.0),
#  ('narvik', 732.0),
#  ('11101992', 732.0),
#  ('drewman', 732.0),
#  ('261056', 731.9090909090909),
#  ('12041998', 731.875),
#  ('molokai', 731.8571428571429),
#  ('chocolate1', 731.8571428571429),
#  ('kourtney', 731.8),
#  ('louloute', 731.75),
#  ('11018', 731.7142857142857),
#  ('16051976', 731.6666666666666),
#  ('sahtm082', 731.6666666666666),
#  ('5115', 731.6666666666666),
#  ('30092000', 731.6428571428571),
#  ('bendog', 731.6),
#  ('marnie', 731.5),
#  ('50898', 731.5),
#  ('12457896', 731.4),
#  ('4223', 731.3333333333334),
#  ('robinn', 731.2857142857143),
#  ('sassie', 731.2222222222222),
#  ('281281', 731.1428571428571),
#  ('batman21', 731.125),
#  ('dancer12', 731.0),
#  ('denis1995', 731.0),
#  ('goblet', 731.0),
#  ('pizdets', 731.0),
#  ('helena', 731.0),
#  ('advantage', 731.0),
#  ('picabo', 730.8888888888889),
#  ('15061961', 730.875),
#  ('estonia', 730.875),
#  ('scabby', 730.8571428571429),
#  ('8127', 730.8571428571429),
#  ('helaman', 730.8181818181819),
#  ('221093', 730.8),
#  ('suffering', 730.8),
#  ('dietcoke', 730.7777777777778),
#  ('morgana', 730.7777777777778),
#  ('leyla', 730.6923076923077),
#  ('takedown', 730.625),
#  ('pickle1', 730.5),
#  ('billygoa', 730.5),
#  ('cobras', 730.5),
#  ('military', 730.4285714285714),
#  ('30071992', 730.3333333333334),
#  ('Jasmine', 730.3333333333334),
#  ('mannn', 730.2222222222222),
#  ('zorglub', 730.1818181818181),
#  ('marmalade', 730.1428571428571),
#  ('140978', 730.1428571428571),
#  ('astana', 730.0),
#  ('135798642', 730.0),
#  ('27121981', 730.0),
#  ('listing', 729.9090909090909),
#  ('151164', 729.9),
#  ('20041997', 729.875),
#  ('150264', 729.8571428571429),
#  ('tankist', 729.8571428571429),
#  ('nihaoma', 729.8333333333334),
#  ('toottoot', 729.8333333333334),
#  ('brian12', 729.8333333333334),
#  ...]

# %%
type(avg_btw_100_900)
# Out:
# list

# %% [markdown]
# ## 3. Find the minimum and maximum on purchase amount inside the dataset formed during Task 2.

# %%
rdd_avg_btw_100_900 = sc.parallelize(avg_btw_100_900)

# %%
type(rdd_avg_btw_100_900)
# Out:
# pyspark.rdd.RDD

# %%
rdd_avg_btw_100_900
# Out:
# ParallelCollectionRDD[217] at parallelize at PythonRDD.scala:195

# %%
min_avg_pur = rdd_avg_btw_100_900.map(lambda x : x[1]).min()
max_avg_pur = rdd_avg_btw_100_900.map(lambda x : x[1]).max()

print('Minimum average amount between 100 and 900 is: ', min_avg_pur)
print('Maximum average amount between 100 and 900 is: ', max_avg_pur)
# Out:
# Minimum average amount between 100 and 900 is:  104.66666666666667
# Maximum average amount between 100 and 900 is:  898.8

# %% [markdown]
# ## 4. Create broadcast data variable which will keep the minimum and maximum values.

# %% [markdown]
# ### 4.1. Use the broadcast variable to implement Min/Max Scaler.

# %%
# define the broadcast dict file, it will broadcast the values to the nodes
# to do
params = sc.broadcast({"min":104.66666666666667, "max":898.8})

def norm(v):
    # define broadcast dict
    return (v-params.value["min"])/(params.value["max"]-params.value["min"])

# %%
type(params)
# Out:
# pyspark.broadcast.Broadcast

# %%
#example 
params.value["min"]/params.value["max"]
# Out:
# 0.11645156504969591

# %% [markdown]
# ### 4.2. Apply Min/Max Scaler on the dataset formed in Task 2.

# %%
type(rdd_avg_btw_100_900)
# Out:
# pyspark.rdd.RDD

# %%
answer = rdd_avg_btw_100_900.map(lambda x : norm (x[1]))

# %% [markdown]
# ### 4.3 Output the first 10 rows from Min/Max Scanner output.

# %%
answer.take(10)
# Out:
# [1.0,
#  0.999622229684352,
#  0.9989926124916052,
#  0.998048186702485,
#  0.9945852921423775,
#  0.9914372061786434,
#  0.9876595030221625,
#  0.9876595030221625,
#  0.9843015446608463,
#  0.9833421279861845]

# %% [markdown]
# ## 5. Use caching to achieve best possible optimization.

# %%
rdd_avg_btw_100_900.cache()
# Out:
# ParallelCollectionRDD[217] at parallelize at PythonRDD.scala:195

# %%
min_value = rdd_avg_btw_100_900.map(lambda x : x[1]).min()
max_value = rdd_avg_btw_100_900.map(lambda x : x[1]).max()
open_sum = rdd_avg_btw_100_900.map(lambda x : x[1]).sum()
volume_std = rdd_avg_btw_100_900.map(lambda x : x[1]).stdev()


print(min_value)
print(max_value)
print(open_sum)
print(volume_std)
# Out:
# 104.66666666666667
# 898.8
# 49823587.30897473
# 96.5480318636
